# %%
import pandas as pd

# %%
df = pd.read_csv('combined_data.csv')

# %%
df
# Out:
#           id tripId   latitude  longitude  bearing  speed   timestamp  \
# 0   vehicle1  trip1  37.791897 -122.39946     32.3    6.7  1723075297
# 1   vehicle1  trip1  37.791897 -122.39946     32.3    6.7  1723075358
# 2   vehicle1  trip1  37.791897 -122.39946     32.3    6.7  1723075419
# 3   vehicle1  trip1  37.791897 -122.39946     32.3    6.7  1723075481
# 4   vehicle1  trip1  37.791897 -122.39946     32.3    6.7  1723075542
# 5   vehicle1  trip1  37.791897 -122.39946     32.3    6.7  1723075603
# 6   vehicle1  trip1  37.791897 -122.39946     32.3    6.7  1723075663
# 7   vehicle1  trip1  37.791897 -122.39946     32.3    6.7  1723075724
# 8   vehicle1  trip1  37.791897 -122.39946     32.3    6.7  1723075785
# 9   vehicle1  trip1  37.791897 -122.39946     32.3    6.7  1723075846
# 10  vehicle1  trip1  37.791897 -122.39946     32.3    6.7  1723075907
# 11  vehicle1  trip1  37.791897 -122.39946     32.3    6.7  1723075968
# ...
