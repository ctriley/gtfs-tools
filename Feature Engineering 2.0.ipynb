# %%
import pandas as pd

# %%
df = pd.read_csv('flattened_data.csv')
# Out:
# C:\Users\maxma\AppData\Local\Temp\ipykernel_25616\1381573417.py:1: DtypeWarning: Columns (11,12,14,15,21,22,23,24,25,26,28) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('flattened_data.csv')

# %%
df
# Out:
#              id tripUpdate.trip.tripId tripUpdate.trip.startTime  \
# 0      63100735               63100735                  14:30:00
# 1      63473633               63473633                  15:10:00
# 2      63071440               63071440                  14:38:00
# 3      63480392               63480392                  14:20:00
# 4      63288413               63288413                  14:44:00
# ...         ...                    ...                       ...
# 51448     y1875                    NaN                       NaN
# 51449     y1927                    NaN                       NaN
# 51450     y2018                    NaN                       NaN
# 51451     y1682                    NaN                       NaN
# 51452      1701                    NaN                       NaN
#
#        tripUpdate.trip.startDate tripUpdate.trip.routeId  \
# 0                     20240815.0                     100
# 1                     20240815.0                  441442
# 2                     20240815.0                      17
# 3                     20240815.0                      28
# 4                     20240815.0                     Red
# ...                          ...                     ...
# 51448                        NaN                     NaN
# 51449                        NaN                     NaN
# 51450                        NaN                     NaN
# 51451                        NaN                     NaN
# 51452                        NaN                     NaN
#
#        tripUpdate.trip.directionId tripUpdate.vehicle.id tripUpdate.timestamp  \
# 0                              0.0                 y1404  2024-08-15 18:20:51
# 1                              0.0                 y3356  2024-08-15 18:20:52
# 2                              1.0                 y1830  2024-08-15 18:20:55
# 3                              0.0                 y1250  2024-08-15 18:20:53
# 4                              0.0            R-547DFF8B                  NaN
# ...                            ...                   ...                  ...
# 51448                          NaN                   NaN                  NaN
# 51449                          NaN                   NaN                  NaN
# 51450                          NaN                   NaN                  NaN
# 51451                          NaN                   NaN                  NaN
# 51452                          NaN                   NaN                  NaN
#
#       tripUpdate.vehicle.label tripUpdate.trip.scheduleRelationship  ...  \
# 0                          NaN                                  NaN  ...
# 1                          NaN                                  NaN  ...
# 2                          NaN                                  NaN  ...
# 3                         1250                                  NaN  ...
# 4                          NaN                                  NaN  ...
# ...                        ...                                  ...  ...
# 51448                      NaN                                  NaN  ...
# 51449                      NaN                                  NaN  ...
# 51450                      NaN                                  NaN  ...
# 51451                      NaN                                  NaN  ...
# 51452                      NaN                                  NaN  ...
#
#       vehicle.currentStatus    vehicle.timestamp vehicle.stopId  \
# 0                       NaN                  NaN            NaN
# 1                       NaN                  NaN            NaN
# 2                       NaN                  NaN            NaN
# 3                       NaN                  NaN            NaN
# 4                       NaN                  NaN            NaN
# ...                     ...                  ...            ...
# 51448            STOPPED_AT  2024-08-15 18:50:51           1514
# 51449         IN_TRANSIT_TO  2024-08-15 18:50:52             73
# 51450         IN_TRANSIT_TO  2024-08-15 18:50:49           5695
# 51451            STOPPED_AT  2024-08-15 18:50:52          37618
# 51452         IN_TRANSIT_TO  2024-08-15 18:50:22     ER-0183-02
#
#        vehicle.vehicle.id vehicle.vehicle.label vehicle.occupancyStatus  \
# 0                     NaN                   NaN                     NaN
# 1                     NaN                   NaN                     NaN
# 2                     NaN                   NaN                     NaN
# 3                     NaN                   NaN                     NaN
# 4                     NaN                   NaN                     NaN
# ...                   ...                   ...                     ...
# 51448               y1875                  1875    MANY_SEATS_AVAILABLE
# 51449               y1927                  1927    MANY_SEATS_AVAILABLE
# 51450               y2018                  2018    MANY_SEATS_AVAILABLE
# 51451               y1682                  1682    MANY_SEATS_AVAILABLE
# 51452                1701                  1701                     NaN
#
#        vehicle.occupancyPercentage  vehicle.multiCarriageDetails  \
# 0                              NaN                           NaN
# 1                              NaN                           NaN
# 2                              NaN                           NaN
# 3                              NaN                           NaN
# 4                              NaN                           NaN
# ...                            ...                           ...
# 51448                         20.0                           NaN
# 51449                         20.0                           NaN
# 51450                          0.0                           NaN
# 51451                          0.0                           NaN
# 51452                          NaN                           NaN
#
#        vehicle.position.speed      first_stop_time
# 0                         NaN  2024-08-15 18:30:00
# 1                         NaN  2024-08-15 19:10:00
# 2                         NaN  2024-08-15 18:38:00
# 3                         NaN  2024-08-15 18:21:09
# 4                         NaN  2024-08-15 18:50:14
# ...                       ...                  ...
# 51448                     NaN                  NaN
# 51449                     NaN                  NaN
# 51450                     NaN                  NaN
# 51451                     NaN                  NaN
# 51452                     7.6                  NaN
#
# [51453 rows x 31 columns]

# %%
for each in df.columns:
    print(each)
# Out:
# id
# tripUpdate.trip.tripId
# tripUpdate.trip.startTime
# tripUpdate.trip.startDate
# tripUpdate.trip.routeId
# tripUpdate.trip.directionId
# tripUpdate.vehicle.id
# tripUpdate.timestamp
# tripUpdate.vehicle.label
# tripUpdate.trip.scheduleRelationship
# source_file
# vehicle.trip.tripId
# vehicle.trip.startTime
# vehicle.trip.startDate
# vehicle.trip.scheduleRelationship
# vehicle.trip.routeId
# vehicle.trip.directionId
# vehicle.position.latitude
# vehicle.position.longitude
# vehicle.position.bearing
# vehicle.currentStopSequence
# vehicle.currentStatus
# vehicle.timestamp
# vehicle.stopId
# vehicle.vehicle.id
# vehicle.vehicle.label
# vehicle.occupancyStatus
# vehicle.occupancyPercentage
# vehicle.multiCarriageDetails
# vehicle.position.speed
# first_stop_time

# %%
# try to create prediction algorithm based on the vertical feature
# notes : try to look at distances between lat / long 
# try to match to the closest point on the route
